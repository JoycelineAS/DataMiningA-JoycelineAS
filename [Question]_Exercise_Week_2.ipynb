# %% [markdown]
# ## Week 2
#
# Please print your name and your NIM.

# %%
print('Joyceline Andriany Suryanto - 0706022210025')
# Out:
# Joyceline Andriany Suryanto - 0706022210025

# %% [markdown]
# ## Pandas

# %% [markdown]
# Please import the necessary library here.

# %%
# Import Library
import pandas as pd

# %% [markdown]
# <h1> Import Data

# %% [markdown]
# Please download the data from zip Elearn. <br>
# then put it on your own github account:
# 1. CSV File (Ice Cream)
# 2. Excel File (Maven Business School)
# 3. JSON File (Drake)
# 4. Text File, add header 'English' and 'France' (eng-fra)
# 5. Web Dataset - https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv
#
# convert the datasets into dataframe using github url.

# %%
# 1
df = pd.read_csv("https://raw.githubusercontent.com/JoycelineAS/DATASET_DATAMINING/refs/heads/main/Ice%20Cream%20Sales%20and%20Temperature.csv")
df.head()
# Out:
#          Date   Time  Temperature (Celsius)  Ice Cream Sales
# 0  2023-01-01  08:00                     18               20
# 1  2023-01-01  08:05                     19               22
# 2  2023-01-01  08:10                     20               25
# 3  2023-01-01  08:15                     21               24
# 4  2023-01-01  08:20                     22               26

# %%
# 2
url = "https://raw.githubusercontent.com/JoycelineAS/DATASET_DATAMINING/main/Maven%20Business%20School.xlsx"
df = pd.read_excel(url, engine='openpyxl')
df.head()
# Out:
#    Student ID  Undergrad Degree  Undergrad Grade  MBA Grade Work Experience  \
# 0           1          Business             68.4       90.2              No
# 1           2          Business             62.1       92.8              No
# 2           3  Computer Science             70.2       68.7             Yes
# 3           4       Engineering             75.1       80.7              No
# 4           5           Finance             60.9       74.9              No
#
#    Employability (Before)  Employability (After)      Status  Annual Salary
# 0                   252.0                  276.0      Placed       111000.0
# 1                   423.0                  410.0  Not Placed            NaN
# 2                   101.0                  119.0      Placed       107000.0
# 3                   288.0                  334.0  Not Placed            NaN
# 4                   248.0                  252.0  Not Placed            NaN

# %%
# 3
df = pd.read_json("https://raw.githubusercontent.com/JoycelineAS/DATASET_DATAMINING/refs/heads/main/drake_data.json")
df.head()
# Out:
#                  album                           lyrics_title  \
# 0  Certified Lover Boy            Certified Lover Boy* Lyrics
# 1  Certified Lover Boy  Like I’m Supposed To/Do Things Lyrics
# 2  Certified Lover Boy                      Not Around Lyrics
# 3  Certified Lover Boy    In the Cut (Ft. Roddy Ricch) Lyrics
# 4  Certified Lover Boy  Zodiac Sign (Ft. Jessie Reyez) Lyrics
#
#                                           lyrics_url  \
# 0  https://genius.com/Drake-certified-lover-boy-l...
# 1  https://genius.com/Drake-like-im-supposed-to-d...
# 2         https://genius.com/Drake-not-around-lyrics
# 3         https://genius.com/Drake-in-the-cut-lyrics
# 4        https://genius.com/Drake-zodiac-sign-lyrics
#
#                                               lyrics track_views
# 0  Lyrics from CLB Merch\n\n[Verse]\nPut my feeli...        8.7K
# 1  [Verse]\nHands are tied\nSomeone's in my ear f...       38.8K
# 2  [Intro]\nYeah, we back\nWassup ladies?\nSwisha...      129.8K
# ...

# %%
# 4
url = "https://raw.githubusercontent.com/JoycelineAS/DATASET_DATAMINING/refs/heads/main/eng-fra.txt"
df = pd.read_csv(url, delimiter='\t', header=None, names=['English', 'Spanish'])
df.head()
df.sample(10)
# Out:
#                                 English  \
# 63931      Heads I win, tails you lose.
# 53301        I can see it in your eyes.
# 20526               Just do what I say.
# 7429                    Open your hand.
# 84765  I'm not sure I'm ready for this.
# 47091         Did you live here before?
# 80056   I'd do anything for those kids.
# 54811        I'll never be that famous.
# 78677   He must have entered this room.
# 75846    It's too sunny to stay inside.
#
#                                                 Spanish
# 63931                     Pile je gagne, face tu perds.
# 53301              Je parviens à le voir dans tes yeux.
# 20526                        Fais juste ce que je dis !
# 7429                                   Ouvrez la main !
# 84765               Je ne suis pas sûre d'y être prête.
# 47091                   Avez-vous vécu ici auparavant ?
# 80056                   Je ferais tout pour ces gamins.
# 54811                  Je ne serai jamais aussi connue.
# ...

# %%
# 5
df = pd.read_csv("https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv")
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# <h1> Try Yourself

# %% [markdown]
# a. Import MLBB HERO DATASET into dataframe <br>
# b. show 10 random data from dataset <br>
# c. Find out if there are any missing values in each column <br>
# d. drop the unnecessary column <br>
# e. show the roles of the hero in that dataset <br>
# f. show the most difficult hero to use<br>
# g. find out which ones has the average higher physical_atk between Fighters and Tank<br>
# output example: <br>
# "Fighters have higher average physical attack than Tanks." <br>
# "Tanks have higher average physical attack than Fighters." <br>
# "Fighters and Tanks have the same average physical attack." <br>
# h. Make a visualization showing percentages of heroes based on their role

# %%
# a
df = pd.read_csv("https://raw.githubusercontent.com/JoycelineAS/DATASET_DATAMINING/refs/heads/main/mlbb_hero.csv", delimiter=';')
df.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
# b
df.sample(10)
# Out:
#          hero_name      role  defense_overall  offense_overall  \
# 79           Hanzo  assassin              6.0              9.0
# 78            Ling  assassin              5.0              8.0
# 16          Lolita      tank              8.0              5.0
# 94         Helcurt  assassin              5.0              9.0
# 69         Balmond   fighter              7.0              6.0
# 37  Popol and Kupa  marksman              3.0              7.0
# 6          Leomord   fighter              6.0              8.0
# 30         Cyclops      mage              4.0              4.0
# 82           Zhask      mage              5.0              5.0
# 88          Wanwan  marksman              3.0              9.0
#
#     skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 79                   5.0                 6.0           260             10
# 78                   6.0                 8.0           260             10
# ...

# %%
# c
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# hero_name                 0
# role                      0
# defense_overall           0
# offense_overall           0
# skill_effect_overall      0
# difficulty_overall        0
# movement_spd              0
# magic_defense             0
# mana                      0
# hp_regen                  0
# physical_atk              0
# physical_defense          0
# hp                        0
# attack_speed              0
# mana_regen                0
# win_rate                  0
# pick_rate                 0
# ban_rate                  0
# release_year              0
# Unnamed: 19             103
# dtype: int64

# %%
# d
df.drop(columns=['Unnamed: 19'], inplace=True)
df.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
# e
roles = df['role'].unique()
print(roles)
# Out:
# ['fighter' 'tank' 'support' 'marksman' 'mage' 'assassin']

# %%
# f
most_difficult_hero = df[df['difficulty_overall'] == df['difficulty_overall'].max()]

hero_name = most_difficult_hero['hero_name'].values[0]
difficulty = most_difficult_hero['difficulty_overall'].values[0]

print(f"The most difficult hero to use is {hero_name}.")
# Out:
# The most difficult hero to use is Fanny.

# %%
# g
average_fighters = sum(fighters_physical_attack) / len(fighters_physical_attack)
average_tanks = sum(tanks_physical_attack) / len(tanks_physical_attack)

print(f"Average physical attack of Fighters: {average_fighters}")
print(f"Average physical attack of Tanks: {average_tanks}")

if average_fighters > average_tanks:
    result = "Fighters have higher average physical attack than Tanks."
elif average_fighters < average_tanks:
    result = "Tanks have higher average physical attack than Fighters."
else:
    result = "Fighters and Tanks have the same average physical attack."

print(result)
# Out:
# Average physical attack of Fighters: 128.0
# Average physical attack of Tanks: 90.0
# Fighters have higher average physical attack than Tanks.

# %%
# h
import matplotlib.pyplot as plt

percentages = df['role'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(percentages, labels=percentages.index, autopct='%1.1f%%')
plt.title('Percentage of Heroes by Role')
plt.show()

# %% [markdown]
# 7. I have a character with this specification:
# defense_overall 6.0<br>
# offense_overall 7.0<br>
# skill_effect_overall 4.0<br>
# difficulty_overall 3.0<br>
# movement_spd 250<br>
# magic_defense 9<br>
# mana 380<br>
# hp_regen 37<br>
# physical_atk 119<br>
# physical_defense 24<br>
# hp 2689<br>
# attack_speed 0.75<br>
# mana_regen 16.0<br>
#
# Please predict its role using DecisionTree classification algorithm <br>

# %%
# 7

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Encode the 'role' column
label_encoder = LabelEncoder()
df['role_encoded'] = label_encoder.fit_transform(df['role'])

# Separate features and target variable
x = df[['defense_overall', 'offense_overall', 'skill_effect_overall', 'difficulty_overall', 'movement_spd', 'magic_defense', 'mana', 'hp_regen', 'physical_atk', 'physical_defense', 'hp', 'attack_speed', 'mana_regen']]
y = df['role_encoded']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=3)

# Create a Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=42)

# Train the model
clf.fit(x_train, y_train)

# Make predictions on the test set
y_pred = clf.predict(x_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of the model:", accuracy)

# Predict the role for the given character
new_character = {
    'defense_overall': 6.0,
    'offense_overall': 7.0,
    'skill_effect_overall': 4.0,
    'difficulty_overall': 3.0,
    'movement_spd': 250,
    'magic_defense': 9,
    'mana': 380,
    'hp_regen': 37,
    'physical_atk': 119,
    'physical_defense': 24,
    'hp': 2689,
    'attack_speed': 0.75,
    'mana_regen': 16.0
}
new_character_df = pd.DataFrame([new_character])

predicted_role_encoded = clf.predict(new_character_df)

# Get the predicted role (dicoding)
predicted_role = label_encoder.inverse_transform(predicted_role_encoded)

print("Predicted role for the new character: ", predicted_role[0])
# Out:
# Accuracy of the model: 0.6666666666666666
# Predicted role for the new character:  fighter

# %% [markdown]
# 8. Why is CSV one of the most commonly used file formats in the field of data science? <br>

# %%
# 8
# CSV (Comma-Separated Values) is a widely used file format in data science due to several key advantages, Simplicity: CSV files are plain text, easy to read and write, with no complex formatting. Each line represents a row, and values are separated by commas. Wide Compatibility: They are supported by various programming languages (like Python and R), data analysis libraries (such as Pandas), and tools (like Tableau), facilitating easy data exchange. Efficiency: CSV files are lightweight, resulting in faster read/write operations, especially with large datasets. Flexibility: Users can customize delimiters and easily accommodate changes in data structure without a strict schema. Data Manipulation: Libraries like Pandas allow for straightforward data manipulation and transformation.Key Differences: Compared to formats like Excel (which supports multiple sheets and advanced features), JSON (better for hierarchical data but more complex), and Parquet/ORC (optimized for big data but less accessible), CSV stands out for its simplicity, compatibility, and efficiency, making it a staple for data import/export and preliminary analysis. Accurate CSV formatting is essential as it will directly influence the reliability and ease of data manipulation. Through well-structured CSV files, seamless import data and export data across various platforms and data integrity can be assured. The stakes are high, however, and even the smallest of discrepancies in CSV formatting can lead to significant data loss or misinterpretation. Therefore, mastering CSV formatting is about adhering to a standardized structure and ensuring the data's accuracy and utility.')

# https://chatgpt.com/share/66f52287-1880-8006-9ba8-f55f6f55ae4b
# https://www.integrate.io/blog/csv-formatting-tips-and-tricks-for-data-accuracy/
